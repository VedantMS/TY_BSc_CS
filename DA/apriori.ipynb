# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# %% [markdown]
# Slip 6

# %%
transactions = [    ['Bread', 'Milk'],
                    ['Bread', 'Diaper', 'Beer', 'Eggs'],
                    ['Milk', 'Diaper', 'Beer', 'Coke'],
                    ['Bread', 'Milk', 'Diaper', 'Beer'],
                    ['Bread', 'Milk', 'Diaper', 'Coke']
                ]

te = TransactionEncoder()

te_array = te.fit(transactions).transform(transactions)     #   Categorical Values into Numerical Format

# %%
df = pd.DataFrame(te_array, columns = te.columns_)
df
# Out:
#     Beer  Bread   Coke  Diaper   Eggs   Milk
# 0  False   True  False   False  False   True
# 1   True   True  False    True   True  False
# 2   True  False   True    True  False   True
# 3   True   True  False    True  False   True
# 4  False   True   True    True  False   True

# %%
freq_items = apriori(df, min_support = 0.5, use_colnames = True)
freq_items
# Out:
#    support                    itemsets
# 0      0.6           frozenset({Beer})
# 1      0.8          frozenset({Bread})
# 2      0.8         frozenset({Diaper})
# 3      0.8           frozenset({Milk})
# 4      0.6   frozenset({Diaper, Beer})
# 5      0.6  frozenset({Diaper, Bread})
# 6      0.6    frozenset({Bread, Milk})
# 7      0.6   frozenset({Diaper, Milk})

# %%
rules = association_rules(freq_items, metric = 'support', min_threshold = 0.05)
rules = rules.sort_values(['support', 'confidence'], ascending = [False, False])

rules
# Out:
#            antecedents          consequents  antecedent support  \
# 1    frozenset({Beer})  frozenset({Diaper})                 0.6
# 0  frozenset({Diaper})    frozenset({Beer})                 0.8
# 2  frozenset({Diaper})   frozenset({Bread})                 0.8
# 3   frozenset({Bread})  frozenset({Diaper})                 0.8
# 4   frozenset({Bread})    frozenset({Milk})                 0.8
# 5    frozenset({Milk})   frozenset({Bread})                 0.8
# 6  frozenset({Diaper})    frozenset({Milk})                 0.8
# 7    frozenset({Milk})  frozenset({Diaper})                 0.8
#
#    consequent support  support  confidence    lift  representativity  \
# 1                 0.8      0.6        1.00  1.2500               1.0
# 0                 0.6      0.6        0.75  1.2500               1.0
# 2                 0.8      0.6        0.75  0.9375               1.0
# 3                 0.8      0.6        0.75  0.9375               1.0
# 4                 0.8      0.6        0.75  0.9375               1.0
# 5                 0.8      0.6        0.75  0.9375               1.0
# 6                 0.8      0.6        0.75  0.9375               1.0
# 7                 0.8      0.6        0.75  0.9375               1.0
#
#    leverage  conviction  zhangs_metric  jaccard  certainty  kulczynski
# 1      0.12         inf           0.50     0.75      1.000       0.875
# 0      0.12         1.6           1.00     0.75      0.375       0.875
# 2     -0.04         0.8          -0.25     0.60     -0.250       0.750
# 3     -0.04         0.8          -0.25     0.60     -0.250       0.750
# 4     -0.04         0.8          -0.25     0.60     -0.250       0.750
# 5     -0.04         0.8          -0.25     0.60     -0.250       0.750
# 6     -0.04         0.8          -0.25     0.60     -0.250       0.750
# 7     -0.04         0.8          -0.25     0.60     -0.250       0.750
